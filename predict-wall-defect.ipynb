# %%
import os
from IPython import display
import ultralytics
from ultralytics import YOLO
from IPython.display import display, Image
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.14 torch-2.4.0.dev20240404 CPU (Apple M1)
# Setup complete ✅ (8 CPUs, 8.0 GB RAM, 221.0/228.3 GB disk)

# %%
# !yolo task=detect mode=predict model=runs/detect/train3/weights/best.pt source=valid/images/istockphoto-622979858-612x612_jpg.rf.ce51dc710cbcab19921e90503305cddc.jpg save=True
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.14 torch-2.4.0.dev20240404 CPU (Apple M1)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /Users/timii/Developer/Students_Projects/Chidinma/datasets/Wall-Defects-Project/valid/images/istockphoto-622979858-612x612_jpg.rf.ce51dc710cbcab19921e90503305cddc.jpg: 640x640 1 peeling_paint, 1 water_seepage, 107.6ms
# Speed: 3.2ms preprocess, 107.6ms inference, 588.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='runs/detect/predict/istockphoto-622979858-612x612_jpg.rf.ce51dc710cbcab19921e90503305cddc.jpg')

# %%
file_name = 'valid/images/istockphoto-1363085939-612x612_jpg.rf.bf43bd9d48b4e36c9e36318e24b13734.jpg'
# !yolo task=detect mode=predict model=runs/detect/train3/weights/best.pt source={file_name} save=True conf=0.25 iou=0.5
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.14 torch-2.4.0.dev20240404 CPU (Apple M1)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /Users/timii/Developer/Students_Projects/Chidinma/datasets/Wall-Defects-Project/valid/images/istockphoto-1363085939-612x612_jpg.rf.bf43bd9d48b4e36c9e36318e24b13734.jpg: 640x640 1 peeling_paint, 1 water_seepage, 173.4ms
# Speed: 3.9ms preprocess, 173.4ms inference, 579.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict9
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename=f'runs/detect/predict9/{os.path.basename(file_name)}')

# %%
file_name = 'valid/images/crack-bb53c022-dc48-11ed-a81a-88b1113a23b0_jpg.rf.3eef68211f0a9671bfc3e433b45a57ca.jpg'
# !yolo task=detect mode=predict model=runs/detect/train4/weights/last.pt source={file_name} save=True conf=0.25 iou=0.5
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.14 torch-2.4.0.dev20240404 CPU (Apple M1)
# Model summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /Users/timii/Developer/Students_Projects/Chidinma/datasets/Wall-Defects-Project/valid/images/crack-bb53c022-dc48-11ed-a81a-88b1113a23b0_jpg.rf.3eef68211f0a9671bfc3e433b45a57ca.jpg: 640x640 1 crack, 84.9ms
# Speed: 5.1ms preprocess, 84.9ms inference, 570.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict11
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename=f'runs/detect/predict11/{os.path.basename(file_name)}')
